# %% [markdown]
# <a href="https://colab.research.google.com/github/IslombekTurakulov/NotebookWorks/blob/main/TurakulovIslombek_Calculus_14_2020_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import sympy
from sympy import S, Symbol, symbols, solve, solveset, plot, plot_parametric, And, plot_implicit
from sympy import sin as Sin
from sympy import cos as Cos
from sympy import exp as Exp
from sympy import log as Log
from sympy import pi as Pi
from sympy.plotting import plot3d
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Занятие 14
# ## Математический анализ
# ## Функции нескольких переменных.
# ### Задание 1
# Изобразить на рисунках область определения функций
#
# 1) $z=\ln(x^2+y)$
#
# 2) $z=\sqrt{\sin(x^2+y^2)}$
#
# 3) $z=\sqrt{x^2-4}+\sqrt{9-y^2}$

# %%
x, y = symbols('x y', real=True)
domainz = (sympy.ln(x*x + y) > 0)
plot_implicit(domainz)

# %%
domainz = (sympy.sqrt(Sin(x*x + y*y)) > 0)
plot_implicit(domainz)

# %%
domainz = (sympy.sqrt(x*x -4 )+ sympy.sqrt(9 - y*y) > 0)
plot_implicit(domainz)

# %% [markdown]
# ### Задача 2.
# Построить на отдельных графиках линии уровня функций $z=\ln(x^2+y)$ и $z=x^2-y^2$.

# %%
C = symbols('C', real=True)
def contourline(f, x, y, C):
 return sympy.Eq(f(x, y), C)

def f(x, y):
 return sympy.ln(x*x + y)

def k(x, y):
 return x*x - y*y

a = plot(ylabel='y', show=False)
p = plot(ylabel='y', show=False)
for item in [(-2, 'blue'), (-1, 'green'), (0, 'red'), (2, 'black'), (5, 'pink')]:
 c, col = item
 p.append(plot_implicit(contourline(k, x, y, c), line_color=col, line_width=15, show=False)[0])
 a.append(plot_implicit(contourline(f, x, y, c), line_color=col, line_width=15, show=False)[0])
p.show() 
a.show()

# %% [markdown]
# ### Задача 3.
# Найти и изобразить поверхности уровня функции $u=(x-1)^2+(y-2)^2+z^2$.

# %%
z, c = symbols('z c')
u = (x - 1)**2 + (y - 2)**2 + z**2
z12 = solve(sympy.Eq(u, c), z)
display(*z12)

plot3d(z12[0].subs(c, -2), z12[1].subs(c, -2))
plot3d(z12[0].subs(c, 2), z12[1].subs(c, 2))
# Out:
# -sqrt(c - x**2 + 2*x - y**2 + 4*y - 5)
# sqrt(c - x**2 + 2*x - y**2 + 4*y - 5)
# /usr/local/lib/python3.7/dist-packages/sympy/plotting/plot.py:1315: UserWarning: Attempting to set identical bottom == top == -0.0 results in singular transformations; automatically expanding.
#   ax.set_zlim(zlim)

# %% [markdown]
# ### Задача 4.
# Найти точки разрыва функции $z=\frac1{(x - y^2)^2}$, изобразить их на графике.

# %%
plot_implicit((x - y**2)**2, (x, -2, 2), (y, -2, 2))

# %% [markdown]
# ### Задача 5.
# Найти частные производные по каждому аргументу функции $u=(xy)^z$

# %%
u = (x*y)**z
display(*(u.diff(t) for t in (x, y, z)))
# Out:
# z*(x*y)**z/x
# z*(x*y)**z/y
# (x*y)**z*log(x*y)

# %% [markdown]
# ### Задача 6.
# Проверить выполнение теоремы Эйлера для функции $f(x,y)=\frac{x}{x^2+y^2} $.
# ###### Указание.
# Упростить выражение с помощью simplify, прежде чем сравнивать.

# %%
k = symbols('k', real=True)
f = x/(x**2 + y**2)
f.simplify().subs({x: k*x, y: k*y})
# Out:
# k*x/(k**2*x**2 + k**2*y**2)

# %%
(x*f.diff(x) + y*f.diff(y)).simplify() == -f
# Out:
# True

# %% [markdown]
# ### Задача 7.
# Найти полный дифференциал функции $z=\sin^2x+\cos^2y$

# %%
z = Sin(x)**2 + Cos(y)**2
dx, dy = symbols('dx dy')
dz = z.diff(x)*dx + z.diff(y)*dy
display(dz)
# Out:
# 2*dx*sin(x)*cos(x) - 2*dy*sin(y)*cos(y)

# %% [markdown]
# ### Индивидуальное задание 139
# Построить линии уровня и найти полный дифференциал функции
# $f(x, y) = -\frac{1}{x^2 - y^2}$.

# %%
z = -1/(x**2 - y**2)
dx, dy = symbols('dx dy')
dz = z.diff(x)*dx + z.diff(y)*dy
display(dz)

def contourLine(f, x, y, C):
  return sympy.Eq(f(x, y), C)

def f(x, y):
  return -1/(x**2 - y**2)

p = plot(ylabel='y', show = False)
for item in [(-2, 'magenta'), (1, 'green')]:
  c, col = item
  p.append(plot_implicit(contourLine(f, x, y, c), line_color=col, line_width = 30, show = False)[0])
p.show()
# Out:
# 2*dx*x/(x**2 - y**2)**2 - 2*dy*y/(x**2 - y**2)**2
